# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

import scipy.optimize as optimization

# %%
class MarkowitzModel:
    def __init__(self, stocks, start_date, end_date):
        self.stocks = stocks.copy()
        self.start_date = start_date
        self.end_date = end_date
        # self.dataset = None

        # Пусть будет 100% в год (хотим удвоить).  
        # x^365 = 2, x - доходность акций
        # x = 1.00190084
        # Берём логарифм. ln(x) = 0.000824740721
        # Модель заменяет её сложную динамику на линейную модель. То есть берёём вместо x среднюю доходность и делаем вид, что она постоянно такая
        self.DOHOD = 0.000824740721
    
    def download_data(self):
        df = {}
        for stock in self.stocks:
            ticker = yf.Ticker(stock)
            df[stock] = ticker.history(start = self.start_date, end = self.end_date, period='1mo')['Close']
        return pd.DataFrame(df)
    
    def show_data(self, data):
        data.plot(figsize = (18,5))
        plt.show()

    def calculate_return(self, data):
        log_return = np.log(data / data.shift(1))
        return log_return[1:]

    def show_statistics(self, returns):
        #annual return using mean
        print(returns.mean())

        #remember covariance is matrix so it will return that
        print(returns.cov())
    
    def show_mean_variance(self, returns, weights):
        portfolio_return = np.sum(returns.mean() * weights)
        portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(returns.cov(), weights)))
        print("Expected portfolio mean(return):", portfolio_return)
        print("Expected portfolio volatility(standerd deviation):", portfolio_volatility)

    def generate_portfolios(self, returns):
        portfolio_means = []
        portfolio_risks = []
        portfolio_weights = []

        for i in range(10000):
            w = np.random.random(len(self.stocks))
            w /= np.sum(w)
            portfolio_weights.append(w)
            # returns.mean() -  среднее по одной акции на протяжении всего времени
            portfolio_means.append(np.sum(returns.mean() * w))
            portfolio_risks.append(np.sqrt(np.dot(w.T, np.dot(returns.cov(), w))))

        return np.array(portfolio_weights), np.array(portfolio_means), np.array(portfolio_risks)
    
    def show_portfolios(self, returns,volatilities):
        plt.figure(figsize = (18,6))
        plt.scatter(volatilities, returns, c = returns / volatilities, marker='o')
        plt.grid(True)
        plt.xlabel('Expected Volatility')
        plt.ylabel('Expected Return')
        plt.colorbar(label = 'Sharp Ratio')
        plt.show()

    def statistics(self, weights, returns):
        portfolio_return = np.sum(returns.mean() * weights)
        portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(returns.cov(), weights)))
        return np.array([portfolio_return, portfolio_volatility, portfolio_return / portfolio_volatility])

    def min_function_sharp(self, weights, returns):
        return self.statistics(weights, returns)[1]
    
    def optimize_portfolio(self, weights, returns):
        constrains = [
            {
            'type': 'eq',
            'fun': lambda x: np.sum(x) - 1
            },
            {
            'type': 'eq',
            'fun': lambda x, returns: np.sum(returns.mean() * x) - self.DOHOD, # lambda x : np.sum(x) - 1
            'args': (returns,)
            },
        ]
        #the weight can be 1 at most for single stock or weights can have value with in 0 and 1
        bounds = tuple((0, 1) for _ in range(len(self.stocks)))
        return optimization.minimize(
            fun = self.min_function_sharp,
            x0 = weights[0],
            args = returns,
            method = 'SLSQP',
            bounds = bounds,
            constraints = constrains
        )
    
    def print_optimal_portfolio(self, optimum, returns):
        print("Optimal portfolio:", optimum['x'].round(3))
        print("Expected return, volatility and sharp ratio:", self.statistics(optimum['x'].round(3), returns))

    def show_optimal_portfolios(self, opt, rets, portfolio_rets, portfolio_vols):
        plt.figure(figsize = (10,6))
        plt.scatter(
            portfolio_vols,
            portfolio_rets,
            c = portfolio_rets / portfolio_vols,
            marker='o'
        )
        plt.grid(True)
        plt.xlabel('Expected Volatility')
        plt.ylabel('Expected Return')
        plt.colorbar(label = 'Sharp Ratio')
        plt.plot(
            self.statistics(opt['x'], rets)[1],
            self.statistics(opt['x'], rets)[0],
            'g*',
            markersize = 20
        )
        plt.show()
    
    # Do all work!
    def get_optimal_weights(self, is_need_graphics = True):
        dataset = self.download_data()

        if is_need_graphics:
            self.show_data(dataset)
        log_daily_returns = self.calculate_return(dataset)
        #show_statistics(log_daily_returns)

        pweights, means, risks = self.generate_portfolios(log_daily_returns)

        if is_need_graphics:
            self.show_portfolios(means, risks)

        optimum = self.optimize_portfolio(pweights, log_daily_returns)
        self.print_optimal_portfolio(optimum, log_daily_returns)

        if is_need_graphics:
            self.show_optimal_portfolios(optimum, log_daily_returns, means, risks)

        return optimum['x'].round(3)

# %%
stocks = ['AAPL', 'WMT', 'TSLA', 'GE', 'AMZN', 'DB']
start_date = '2018-01-01'
end_date = '2024-01-01'

# %%
model = MarkowitzModel(stocks, start_date, end_date)
model.get_optimal_weights()
# Out:
# Optimal portfolio: [0.487 0.411 0.102 0.    0.    0.   ]
# Expected return, volatility and sharp ratio: [0.00082461 0.01521788 0.05418709]
# array([0.487, 0.411, 0.102, 0.   , 0.   , 0.   ])

# %% [markdown]
# ## Попытка в ребалансировку
#
# Смотреть тут: https://readmedium.com/en/https:/python.plainenglish.io/how-to-improve-investment-portfolio-with-rebalancing-strategy-in-python-a58841ee8b5e

# %%
stocks = ['AAPL', 'WMT', 'TSLA', 'GE', 'AMZN', 'DB']

# %%
df = {}
for stock in stocks:
    ticker = yf.Ticker(stock)
    df[stock] = ticker.history(start = start_date, end = end_date, period='1mo')['Close']

df = pd.DataFrame(df)
returns = np.log(df / df.shift(1))[1:]
returns
# Out:
#                                AAPL       WMT      TSLA        GE      AMZN  \
# Date
# 2018-01-03 00:00:00-05:00 -0.000174  0.008685 -0.010286  0.009410  0.012694
# 2018-01-04 00:00:00-05:00  0.004634  0.000904 -0.008325  0.020721  0.004466
# 2018-01-05 00:00:00-05:00  0.011321  0.005910  0.006210  0.000539  0.016033
# 2018-01-08 00:00:00-05:00 -0.003721  0.014673  0.060755 -0.014123  0.014322
# 2018-01-09 00:00:00-05:00 -0.000115 -0.012079 -0.008118  0.015201  0.004665
# ...                             ...       ...       ...       ...       ...
# 2023-12-22 00:00:00-05:00 -0.005563  0.011880 -0.007731 -0.002208 -0.002734
# 2023-12-26 00:00:00-05:00 -0.002845 -0.001533  0.015988  0.006138 -0.000065
# 2023-12-27 00:00:00-05:00  0.000518  0.009355  0.018647  0.006497 -0.000456
# 2023-12-28 00:00:00-05:00  0.002224 -0.001965 -0.032104  0.000936  0.000261
# 2023-12-29 00:00:00-05:00 -0.005439  0.000508 -0.018738 -0.005392 -0.009433
#
#                                  DB
# Date
# 2018-01-03 00:00:00-05:00 -0.008834
# 2018-01-04 00:00:00-05:00  0.031341
# 2018-01-05 00:00:00-05:00 -0.063696
# 2018-01-08 00:00:00-05:00 -0.013569
# 2018-01-09 00:00:00-05:00 -0.009333
# ...                             ...
# 2023-12-22 00:00:00-05:00  0.010302
# 2023-12-26 00:00:00-05:00  0.005111
# 2023-12-27 00:00:00-05:00  0.002909
# 2023-12-28 00:00:00-05:00 -0.010953
# 2023-12-29 00:00:00-05:00 -0.005153
#
# [1508 rows x 6 columns]

# %%
import datetime
from dateutil.relativedelta import relativedelta
import heapq

# %%
def portfolio(stocks, dataset, numStocks, numRev):
    selected_stocks = stocks.copy()
    
    # Будем каждый месяц делать ребалансировку. Стартовая дата - 2018-01-01. Конечная дата - 2024-01-01.
    start_month = 1
    start_year = 2018
    end_month = 1
    end_year = 2024
    curr_datetime = datetime.datetime(start_year, start_month, 1)
    next_datetime = curr_datetime + relativedelta(months=1)
    end_datetime = datetime.datetime(end_year, end_month, 1)

    i = 0
    while next_datetime + relativedelta(months=1) < end_datetime:
        next_datetime = curr_datetime + relativedelta(months=1)

        if len(selected_stocks) > 0:
            # Модель Марковица: считаем оптимальные веса для выбранных акций за месяц
            month_model = MarkowitzModel(selected_stocks, curr_datetime.strftime("%Y-%m-%d"), next_datetime.strftime("%Y-%m-%d"))
            weights = month_model.get_optimal_weights(is_need_graphics=False)

            values = np.array(weights * df[selected_stocks].iloc[i,:])
            indexes_of_max_value = heapq.nsmallest(numRev, range(len(values)), values.take)

            # убираем numRev наименее доходных акций
            selected_stocks = [stocks[ind] for ind in range(len(stocks)) if ind not in indexes_of_max_value]
        
        current_month_returns = np.array(df.iloc[i,:])
        # Добавляем ещё наиболее доходных акций в количестве numStocks - numRev.
        # Сортирую в порядке убывания по доходности за месяц
        indexes_of_max_value = heapq.nlargest(len(stocks), range(len(current_month_returns)), current_month_returns.take)
        
        # Хотим добавлять только те акции, которых еще нет в selected_stocks
        for ind in indexes_of_max_value:
            if stocks[ind] in selected_stocks:
                continue
            if len(selected_stocks) == numStocks:
                break
            selected_stocks.append(stocks[ind])


        print("From {} to {} was selected {}\n".format(
            curr_datetime.strftime("%Y-%m-%d"),
            next_datetime.strftime("%Y-%m-%d"),
            selected_stocks
        ))

        i += 1
        curr_datetime = next_datetime

    # Рассчитываем для финального месяца: просто запускаем Марковица для вычисления весов
    month_model = MarkowitzModel(selected_stocks, curr_datetime.strftime("%Y-%m-%d"), end_datetime.strftime("%Y-%m-%d"))
    weights = month_model.get_optimal_weights()
    returns = np.array(weights * df[selected_stocks].iloc[i,:])
    print("-----------------------------------------------------")
    print("------------------- Final results -------------------")
    print("Selected stock:", selected_stocks)
    print("Weights:", weights)
    print("Returns:", returns)
    print("-----------------------------------------------------")

    return weights, returns

# %%
print(stocks)
rebalanced_portfolio = portfolio(stocks, df, 4, 2)
# Out:
# ['AAPL', 'WMT', 'TSLA', 'GE', 'AMZN', 'DB']
# Optimal portfolio: [0.419 0.274 0.013 0.099 0.105 0.089]
# Expected return, volatility and sharp ratio: [0.00082536 0.00601259 0.13727224]
# From 2018-01-01 to 2018-02-01 was selected ['AAPL', 'WMT', 'GE', 'AMZN']
#
# Optimal portfolio: [0.239 0.193 0.088 0.48 ]
# Expected return, volatility and sharp ratio: [0.00082473 0.0184754  0.04463933]
# From 2018-02-01 to 2018-03-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1. 0.]
# Expected return, volatility and sharp ratio: [-0.00156808  0.02140548 -0.07325589]
# From 2018-03-01 to 2018-04-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.    0.112 0.074 0.814]
# Expected return, volatility and sharp ratio: [0.00082161 0.01529443 0.05371942]
# From 2018-04-01 to 2018-05-01 was selected ['WMT', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.115 0.105 0.779 0.   ]
# Expected return, volatility and sharp ratio: [0.00082516 0.00576647 0.14309671]
# From 2018-05-01 to 2018-06-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.492 0.    0.28  0.227]
# Expected return, volatility and sharp ratio: [0.00082415 0.00659719 0.12492417]
# From 2018-06-01 to 2018-07-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.844 0.02  0.136 0.   ]
# Expected return, volatility and sharp ratio: [0.00082663 0.00945997 0.0873817 ]
# From 2018-07-01 to 2018-08-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.57  0.048 0.    0.382]
# Expected return, volatility and sharp ratio: [0.00082768 0.00836677 0.0989244 ]
# From 2018-08-01 to 2018-09-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 0. 1.]
# Expected return, volatility and sharp ratio: [-0.00029266  0.01670336 -0.0175211 ]
# From 2018-09-01 to 2018-10-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.741 0.161 0.    0.098]
# Expected return, volatility and sharp ratio: [0.00082434 0.03415281 0.02413691]
# From 2018-10-01 to 2018-11-01 was selected ['AAPL', 'WMT', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1. 0.]
# Expected return, volatility and sharp ratio: [0.00073429 0.03066313 0.02394692]
# From 2018-11-01 to 2018-12-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0. 0.]
# Expected return, volatility and sharp ratio: [-0.0016383   0.03875748 -0.0422705 ]
# From 2018-12-01 to 2019-01-01 was selected ['WMT', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00131634 0.00873658 0.15066962]
# From 2019-01-01 to 2019-02-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.186 0.    0.814 0.   ]
# Expected return, volatility and sharp ratio: [0.00082428 0.01031599 0.07990315]
# From 2019-02-01 to 2019-03-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.332 0.238 0.3   0.129]
# Expected return, volatility and sharp ratio: [0.00082455 0.01270383 0.06490574]
# From 2019-03-01 to 2019-04-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.233 0.058 0.426 0.283]
# Expected return, volatility and sharp ratio: [0.00082985 0.00635466 0.13058918]
# From 2019-04-01 to 2019-05-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1. 0.]
# Expected return, volatility and sharp ratio: [-0.00352661  0.01573133 -0.22417747]
# From 2019-05-01 to 2019-06-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00516505 0.0178624  0.28915783]
# From 2019-06-01 to 2019-07-01 was selected ['WMT', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.194 0.    0.    0.806]
# Expected return, volatility and sharp ratio: [0.0008246  0.01830449 0.04504908]
# From 2019-07-01 to 2019-08-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00025135 0.02352312 0.01068529]
# From 2019-08-01 to 2019-09-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.385 0.002 0.587 0.025]
# Expected return, volatility and sharp ratio: [0.0008222  0.0106433  0.07725023]
# From 2019-09-01 to 2019-10-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.    0.    0.777 0.223]
# Expected return, volatility and sharp ratio: [0.00082479 0.0106525  0.07742712]
# From 2019-10-01 to 2019-11-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.124 0.061 0.815 0.   ]
# Expected return, volatility and sharp ratio: [0.00082517 0.00704626 0.11710776]
# From 2019-11-01 to 2019-12-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.871 0.06  0.07  0.   ]
# Expected return, volatility and sharp ratio: [0.00082933 0.00483735 0.17144232]
# From 2019-12-01 to 2020-01-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00150211 0.01778646 0.08445263]
# From 2020-01-01 to 2020-02-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 0. 1.]
# Expected return, volatility and sharp ratio: [-0.00150838  0.04180888 -0.03607804]
# From 2020-02-01 to 2020-03-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1. 0.]
# Expected return, volatility and sharp ratio: [-0.0001032   0.04150709 -0.00248634]
# From 2020-03-01 to 2020-04-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.    0.826 0.174 0.   ]
# Expected return, volatility and sharp ratio: [0.00082893 0.03452527 0.02400931]
# From 2020-04-01 to 2020-05-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.961 0.    0.039 0.   ]
# Expected return, volatility and sharp ratio: [0.00082472 0.00954661 0.08638896]
# From 2020-05-01 to 2020-06-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00434391 0.03716596 0.11687864]
# From 2020-06-01 to 2020-07-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.009 0.395 0.597 0.   ]
# Expected return, volatility and sharp ratio: [0.00082826 0.01744657 0.04747437]
# From 2020-07-01 to 2020-08-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00165348 0.0183813  0.0899546 ]
# From 2020-08-01 to 2020-09-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00042555 0.03761953 0.01131195]
# From 2020-09-01 to 2020-10-01 was selected ['WMT', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.689 0.098 0.    0.212]
# Expected return, volatility and sharp ratio: [0.00082131 0.00821675 0.09995553]
# From 2020-10-01 to 2020-11-01 was selected ['AAPL', 'WMT', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1. 0.]
# Expected return, volatility and sharp ratio: [0.00278992 0.02392818 0.11659573]
# From 2020-11-01 to 2020-12-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.    0.271 0.595 0.134]
# Expected return, volatility and sharp ratio: [0.00082418 0.00794717 0.10370793]
# From 2020-12-01 to 2021-01-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.135 0.196 0.668 0.   ]
# Expected return, volatility and sharp ratio: [0.00082358 0.01672079 0.0492551 ]
# From 2021-01-01 to 2021-02-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.043 0.    0.582 0.375]
# Expected return, volatility and sharp ratio: [0.00082624 0.00671787 0.12299165]
# From 2021-02-01 to 2021-03-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0. 0.]
# Expected return, volatility and sharp ratio: [0.0001113  0.03219796 0.00345665]
# From 2021-03-01 to 2021-04-01 was selected ['WMT', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.592 0.389 0.    0.019]
# Expected return, volatility and sharp ratio: [0.00082304 0.0072847  0.11298238]
# From 2021-04-01 to 2021-05-01 was selected ['AAPL', 'WMT', 'AMZN', 'DB']
#
# Optimal portfolio: [0.    0.614 0.157 0.229]
# Expected return, volatility and sharp ratio: [0.00082708 0.00876363 0.09437655]
# From 2021-05-01 to 2021-06-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.313 0.04  0.518 0.129]
# Expected return, volatility and sharp ratio: [0.00083085 0.00570998 0.14550815]
# From 2021-06-01 to 2021-07-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.4   0.289 0.202 0.109]
# Expected return, volatility and sharp ratio: [0.0008236  0.0106709  0.07718188]
# From 2021-07-01 to 2021-08-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.365 0.    0.085 0.55 ]
# Expected return, volatility and sharp ratio: [0.0008238  0.00885498 0.09303215]
# From 2021-08-01 to 2021-09-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00079367 0.02405076 0.03299964]
# From 2021-09-01 to 2021-10-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.028 0.549 0.423 0.   ]
# Expected return, volatility and sharp ratio: [0.0008268  0.01114321 0.07419725]
# From 2021-10-01 to 2021-11-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.245 0.089 0.665 0.   ]
# Expected return, volatility and sharp ratio: [0.00082712 0.01267936 0.06523332]
# From 2021-11-01 to 2021-12-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.253 0.    0.432 0.316]
# Expected return, volatility and sharp ratio: [0.00082655 0.01317478 0.06273757]
# From 2021-12-01 to 2022-01-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.48  0.    0.031 0.489]
# Expected return, volatility and sharp ratio: [0.0008264  0.01795595 0.0460236 ]
# From 2022-01-01 to 2022-02-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.    0.017 0.983 0.   ]
# Expected return, volatility and sharp ratio: [0.0008254  0.04105494 0.02010487]
# From 2022-02-01 to 2022-03-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1. 0.]
# Expected return, volatility and sharp ratio: [0.0034325  0.02627966 0.13061445]
# From 2022-03-01 to 2022-04-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0. 0.]
# Expected return, volatility and sharp ratio: [-0.01134897  0.02789635 -0.40682623]
# From 2022-04-01 to 2022-05-01 was selected ['WMT', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.209 0.54  0.    0.251]
# Expected return, volatility and sharp ratio: [0.00082272 0.02009825 0.04093483]
# From 2022-05-01 to 2022-06-01 was selected ['AAPL', 'WMT', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0. 0.]
# Expected return, volatility and sharp ratio: [-0.00156673  0.01403315 -0.11164525]
# From 2022-06-01 to 2022-07-01 was selected ['WMT', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00153277 0.0303678  0.05047358]
# From 2022-07-01 to 2022-08-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0. 0.]
# Expected return, volatility and sharp ratio: [-0.00143771  0.01896259 -0.07581824]
# From 2022-08-01 to 2022-09-01 was selected ['WMT', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0. 0.]
# Expected return, volatility and sharp ratio: [-0.00180957  0.01282111 -0.14113977]
# From 2022-09-01 to 2022-10-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.388 0.195 0.417 0.   ]
# Expected return, volatility and sharp ratio: [0.00082494 0.02244534 0.03675328]
# From 2022-10-01 to 2022-11-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.216 0.23  0.    0.555]
# Expected return, volatility and sharp ratio: [0.00082113 0.02423424 0.03388303]
# From 2022-11-01 to 2022-12-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.025 0.421 0.127 0.427]
# Expected return, volatility and sharp ratio: [0.00082186 0.01643916 0.0499943 ]
# From 2022-12-01 to 2023-01-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.895 0.    0.    0.105]
# Expected return, volatility and sharp ratio: [0.00082524 0.01117483 0.07384839]
# From 2023-01-01 to 2023-02-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.212 0.687 0.    0.101]
# Expected return, volatility and sharp ratio: [0.00082389 0.00949612 0.08676049]
# From 2023-02-01 to 2023-03-01 was selected ['AAPL', 'WMT', 'AMZN', 'DB']
#
# Optimal portfolio: [0.    0.854 0.    0.146]
# Expected return, volatility and sharp ratio: [0.00082948 0.00879465 0.09431598]
# From 2023-03-01 to 2023-04-01 was selected ['WMT', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00084542 0.00667697 0.12661793]
# From 2023-04-01 to 2023-05-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.38  0.546 0.003 0.071]
# Expected return, volatility and sharp ratio: [0.00082678 0.01102804 0.07497072]
# From 2023-05-01 to 2023-06-01 was selected ['AAPL', 'WMT', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00100723 0.01515273 0.06647174]
# From 2023-06-01 to 2023-07-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.326 0.446 0.216 0.011]
# Expected return, volatility and sharp ratio: [0.00082444 0.01331452 0.0619202 ]
# From 2023-07-01 to 2023-08-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.743 0.    0.034 0.223]
# Expected return, volatility and sharp ratio: [0.00082527 0.0073274  0.11262857]
# From 2023-08-01 to 2023-09-01 was selected ['AAPL', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00048109 0.01678675 0.02865913]
# From 2023-09-01 to 2023-10-01 was selected ['TSLA', 'GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.018 0.342 0.204 0.436]
# Expected return, volatility and sharp ratio: [0.00081986 0.0149043  0.05500822]
# From 2023-10-01 to 2023-11-01 was selected ['WMT', 'TSLA', 'AMZN', 'DB']
#
# Optimal portfolio: [0.429 0.    0.489 0.082]
# Expected return, volatility and sharp ratio: [0.00082721 0.01124132 0.07358691]
# From 2023-11-01 to 2023-12-01 was selected ['AAPL', 'TSLA', 'AMZN', 'DB']
# Optimal portfolio: [0.823 0.    0.07  0.106]
# Expected return, volatility and sharp ratio: [0.00082219 0.00826385 0.09949186]
# -----------------------------------------------------
# ------------------- Final results -------------------
# Selected stock: ['AAPL', 'TSLA', 'AMZN', 'DB']
# Weights: [0.823 0.    0.07  0.106]
# Returns: [34.30325873  0.          5.04524979  1.40205647]
# -----------------------------------------------------
