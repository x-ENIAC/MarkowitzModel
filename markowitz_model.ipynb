# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

import scipy.optimize as optimization

# %%
class MarkowitzModel:
    def __init__(self, stocks, start_date, end_date):
        self.stocks = stocks.copy()
        self.start_date = start_date
        self.end_date = end_date
        # self.dataset = None

        # Пусть будет 100% в год (хотим удвоить).  
        # x^365 = 2, x - доходность акций
        # x = 1.00190084
        # Берём логарифм. ln(x) = 0.000824740721
        # Модель заменяет её сложную динамику на линейную модель. То есть берёём вместо x среднюю доходность и делаем вид, что она постоянно такая
        self.DOHOD = 0.000824740721
    
    def download_data(self):
        df = {}
        for stock in self.stocks:
            ticker = yf.Ticker(stock)
            df[stock] = ticker.history(start = self.start_date, end = self.end_date, period='1mo')['Close']
        return pd.DataFrame(df)
    
    def show_data(self, data):
        data.plot(figsize = (18,5))
        plt.show()

    def calculate_return(self, data):
        log_return = np.log(data / data.shift(1))
        return log_return[1:]

    def show_statistics(self, returns):
        #annual return using mean
        print(returns.mean())

        #remember covariance is matrix so it will return that
        print(returns.cov())
    
    def show_mean_variance(self, returns, weights):
        portfolio_return = np.sum(returns.mean() * weights)
        portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(returns.cov(), weights)))
        print("Expected portfolio mean(return):", portfolio_return)
        print("Expected portfolio volatility(standerd deviation):", portfolio_volatility)

    def generate_portfolios(self, returns):
        portfolio_means = []
        portfolio_risks = []
        portfolio_weights = []

        for i in range(10000):
            w = np.random.random(len(self.stocks))
            w /= np.sum(w)
            portfolio_weights.append(w)
            # returns.mean() -  среднее по одной акции на протяжении всего времени
            portfolio_means.append(np.sum(returns.mean() * w))
            portfolio_risks.append(np.sqrt(np.dot(w.T, np.dot(returns.cov(), w))))

        return np.array(portfolio_weights), np.array(portfolio_means), np.array(portfolio_risks)
    
    def show_portfolios(self, returns,volatilities):
        plt.figure(figsize = (18,6))
        plt.scatter(volatilities, returns, c = returns / volatilities, marker='o')
        plt.grid(True)
        plt.xlabel('Expected Volatility')
        plt.ylabel('Expected Return')
        plt.colorbar(label = 'Sharp Ratio')
        plt.show()

    def statistics(self, weights, returns):
        portfolio_return = np.sum(returns.mean() * weights)
        portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(returns.cov(), weights)))
        return np.array([portfolio_return, portfolio_volatility, portfolio_return / portfolio_volatility])

    def min_function_sharp(self, weights, returns):
        return self.statistics(weights, returns)[1]
    
    def optimize_portfolio(self, weights, returns):
        constrains = [
            {
            'type': 'eq',
            'fun': lambda x: np.sum(x) - 1
            },
            {
            'type': 'eq',
            'fun': lambda x, returns: np.sum(returns.mean() * x) - self.DOHOD, # lambda x : np.sum(x) - 1
            'args': (returns,)
            },
        ]
        #the weight can be 1 at most for single stock or weights can have value with in 0 and 1
        bounds = tuple((0, 1) for _ in range(len(self.stocks)))
        return optimization.minimize(
            fun = self.min_function_sharp,
            x0 = weights[0],
            args = returns,
            method = 'SLSQP',
            bounds = bounds,
            constraints = constrains
        )
    
    def print_optimal_portfolio(self, optimum, returns):
        print("Optimal portfolio:", optimum['x'].round(3))
        print("Expected return, volatility and sharp ratio:", self.statistics(optimum['x'].round(3), returns))

    def show_optimal_portfolios(self, opt, rets, portfolio_rets, portfolio_vols):
        plt.figure(figsize = (10,6))
        plt.scatter(
            portfolio_vols,
            portfolio_rets,
            c = portfolio_rets / portfolio_vols,
            marker='o'
        )
        plt.grid(True)
        plt.xlabel('Expected Volatility')
        plt.ylabel('Expected Return')
        plt.colorbar(label = 'Sharp Ratio')
        plt.plot(
            self.statistics(opt['x'], rets)[1],
            self.statistics(opt['x'], rets)[0],
            'g*',
            markersize = 20
        )
        plt.show()
    
    # Do all work!
    def get_optimal_weights(self, is_need_graphics = True):
        dataset = self.download_data()

        if is_need_graphics:
            self.show_data(dataset)
        log_daily_returns = self.calculate_return(dataset)
        #show_statistics(log_daily_returns)

        pweights, means, risks = self.generate_portfolios(log_daily_returns)

        if is_need_graphics:
            self.show_portfolios(means, risks)

        optimum = self.optimize_portfolio(pweights, log_daily_returns)
        self.print_optimal_portfolio(optimum, log_daily_returns)

        if is_need_graphics:
            self.show_optimal_portfolios(optimum, log_daily_returns, means, risks)

        return optimum['x'].round(3)

# %%
stocks = ['AAPL', 'WMT', 'TSLA', 'GE', 'AMZN', 'DB']
start_date = '2018-01-01'
end_date = '2024-01-01'

# %%
model = MarkowitzModel(stocks, start_date, end_date)
model.get_optimal_weights()
# Out:
# Optimal portfolio: [0.489 0.41  0.101 0.    0.    0.   ]
# Expected return, volatility and sharp ratio: [0.00082466 0.01521933 0.05418529]
# array([0.489, 0.41 , 0.101, 0.   , 0.   , 0.   ])

# %% [markdown]
# ## Попытка в ребалансировку

# %%
stocks = ['AAPL', 'WMT', 'TSLA', 'GE', 'AMZN', 'DB']

# %%
df = {}
for stock in stocks:
    ticker = yf.Ticker(stock)
    df[stock] = ticker.history(start = start_date, end = end_date, period='1mo')['Close']

df = pd.DataFrame(df)
returns = np.log(df / df.shift(1))[1:]
returns
# Out:
#                                AAPL       WMT      TSLA        GE      AMZN  \
# Date
# 2018-01-03 00:00:00-05:00 -0.000174  0.008685 -0.010286  0.009410  0.012694
# 2018-01-04 00:00:00-05:00  0.004634  0.000905 -0.008325  0.020720  0.004466
# 2018-01-05 00:00:00-05:00  0.011321  0.005910  0.006210  0.000540  0.016033
# 2018-01-08 00:00:00-05:00 -0.003721  0.014673  0.060755 -0.014123  0.014322
# 2018-01-09 00:00:00-05:00 -0.000115 -0.012080 -0.008118  0.015201  0.004665
# ...                             ...       ...       ...       ...       ...
# 2023-12-22 00:00:00-05:00 -0.005563  0.011880 -0.007731 -0.002208 -0.002734
# 2023-12-26 00:00:00-05:00 -0.002845 -0.001533  0.015988  0.006138 -0.000065
# 2023-12-27 00:00:00-05:00  0.000518  0.009355  0.018647  0.006497 -0.000456
# 2023-12-28 00:00:00-05:00  0.002224 -0.001965 -0.032104  0.000936  0.000261
# 2023-12-29 00:00:00-05:00 -0.005439  0.000508 -0.018738 -0.005392 -0.009433
#
#                                  DB
# Date
# 2018-01-03 00:00:00-05:00 -0.008833
# 2018-01-04 00:00:00-05:00  0.031341
# 2018-01-05 00:00:00-05:00 -0.063696
# 2018-01-08 00:00:00-05:00 -0.013569
# 2018-01-09 00:00:00-05:00 -0.009333
# ...                             ...
# 2023-12-22 00:00:00-05:00  0.010302
# 2023-12-26 00:00:00-05:00  0.005111
# 2023-12-27 00:00:00-05:00  0.002909
# 2023-12-28 00:00:00-05:00 -0.010953
# 2023-12-29 00:00:00-05:00 -0.005153
#
# [1508 rows x 6 columns]

# %%
import datetime
from dateutil.relativedelta import relativedelta
import heapq

# %%
def portfolio(stocks, dataset, numStocks, numRev):
    selected_stocks = stocks.copy()
    
    # Будем каждый месяц делать ребалансировку. Стартовая дата - 2018-01-01. Конечная дата - 2024-01-01.
    start_month = 1
    start_year = 2018
    end_month = 1
    end_year = 2024
    curr_datetime = datetime.datetime(start_year, start_month, 1)
    next_datetime = curr_datetime + relativedelta(months=1)
    end_datetime = datetime.datetime(end_year, end_month, 1)

    i = 0
    while next_datetime + relativedelta(months=1) < end_datetime:
        next_datetime = curr_datetime + relativedelta(months=1)

        if len(selected_stocks) > 0:
            # Модель Марковица: считаем оптимальные веса для выбранных акций за месяц
            month_model = MarkowitzModel(selected_stocks, curr_datetime.strftime("%Y-%m-%d"), next_datetime.strftime("%Y-%m-%d"))
            weights = month_model.get_optimal_weights(is_need_graphics=False)

            values = np.array(weights * df[selected_stocks].iloc[i,:])
            indexes_of_max_value = heapq.nsmallest(numRev, range(len(values)), values.take)

            # отметаем numRev наименее доходных акций
            selected_stocks = [stocks[ind] for ind in range(len(stocks)) if ind not in indexes_of_max_value]

        # fillNum = numStocks - len(selected_stocks)
        
        # Добавляем ещё numStocks - numRev наиболее доходные акции. Тут чутка странно.
        # Смотреть тут: https://readmedium.com/en/https:/python.plainenglish.io/how-to-improve-investment-portfolio-with-rebalancing-strategy-in-python-a58841ee8b5e
        indexes_of_max_value = heapq.nlargest(len(stocks), range(len(values)), values.take)

        for ind in indexes_of_max_value:
            if stocks[ind] in selected_stocks:
                continue
            if len(selected_stocks) == numStocks:
                break
            selected_stocks.append(stocks[ind])


        print("From {} to {} was selected {}\n".format(
            curr_datetime.strftime("%Y-%m-%d"),
            next_datetime.strftime("%Y-%m-%d"),
            selected_stocks
        ))

        i += 1
        curr_datetime = next_datetime

    # Рассчитываем для финального месяца
    month_model = MarkowitzModel(selected_stocks, curr_datetime.strftime("%Y-%m-%d"), end_datetime.strftime("%Y-%m-%d"))
    weights = month_model.get_optimal_weights()
    returns = np.array(weights * df[selected_stocks].iloc[i,:])
    print("-----------------------------------------------------")
    print("------------------- Final results -------------------")
    print("Selected stock:", selected_stocks)
    print("Weights:", weights)
    print("Returns:", returns)
    print("-----------------------------------------------------")

    return weights, returns

# %%
rebalanced_portfolio = portfolio(stocks, df, 3, 4)
# Out:
# Optimal portfolio: [0.421 0.27  0.021 0.096 0.101 0.09 ]
# Expected return, volatility and sharp ratio: [0.00082044 0.0060164  0.13636767]
# From 2018-01-01 to 2018-02-01 was selected ['AAPL', 'WMT', 'GE']
#
# Optimal portfolio: [0.76  0.134 0.107]
# Expected return, volatility and sharp ratio: [0.0008201  0.02138679 0.03834628]
# From 2018-02-01 to 2018-03-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0.]
# Expected return, volatility and sharp ratio: [-0.00156808  0.02140548 -0.07325589]
# From 2018-03-01 to 2018-04-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.112 0.074 0.814]
# Expected return, volatility and sharp ratio: [0.00082161 0.01529443 0.05371955]
# From 2018-04-01 to 2018-05-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.127 0.834 0.039]
# Expected return, volatility and sharp ratio: [0.00082463 0.00628066 0.1312959 ]
# From 2018-05-01 to 2018-06-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.131 0.725 0.144]
# Expected return, volatility and sharp ratio: [0.00082592 0.01089761 0.07578889]
# From 2018-06-01 to 2018-07-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00096299 0.01674108 0.05752272]
# From 2018-07-01 to 2018-08-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.518 0.385 0.097]
# Expected return, volatility and sharp ratio: [0.000826   0.00980025 0.08428324]
# From 2018-08-01 to 2018-09-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1.]
# Expected return, volatility and sharp ratio: [-0.00029265  0.01670335 -0.01752052]
# From 2018-09-01 to 2018-10-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1.]
# Expected return, volatility and sharp ratio: [-0.00641144  0.01860632 -0.34458388]
# From 2018-10-01 to 2018-11-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0.]
# Expected return, volatility and sharp ratio: [0.00073429 0.03066313 0.02394692]
# From 2018-11-01 to 2018-12-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0.]
# Expected return, volatility and sharp ratio: [-0.00163829  0.03875743 -0.04227039]
# From 2018-12-01 to 2019-01-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00398337 0.02998493 0.13284584]
# From 2019-01-01 to 2019-02-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.058 0.838 0.104]
# Expected return, volatility and sharp ratio: [0.00082589 0.01169755 0.07060374]
# From 2019-02-01 to 2019-03-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.131 0.692 0.177]
# Expected return, volatility and sharp ratio: [0.00082222 0.01487782 0.05526505]
# From 2019-03-01 to 2019-04-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.093 0.488 0.419]
# Expected return, volatility and sharp ratio: [0.00082572 0.00703036 0.11745075]
# From 2019-04-01 to 2019-05-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0.]
# Expected return, volatility and sharp ratio: [-0.00321808  0.01828478 -0.17599748]
# From 2019-05-01 to 2019-06-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00516505 0.01786243 0.28915706]
# From 2019-06-01 to 2019-07-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.    0.091 0.909]
# Expected return, volatility and sharp ratio: [0.00082585 0.02068044 0.03993403]
# From 2019-07-01 to 2019-08-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0.]
# Expected return, volatility and sharp ratio: [-0.00207287  0.01707502 -0.12139781]
# From 2019-08-01 to 2019-09-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.451 0.549 0.   ]
# Expected return, volatility and sharp ratio: [0.00082565 0.013162   0.06272985]
# From 2019-09-01 to 2019-10-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.    0.777 0.223]
# Expected return, volatility and sharp ratio: [0.00082479 0.0106525  0.07742712]
# From 2019-10-01 to 2019-11-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.136 0.864 0.   ]
# Expected return, volatility and sharp ratio: [0.00082581 0.0075354  0.10959074]
# From 2019-11-01 to 2019-12-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.566 0.434 0.   ]
# Expected return, volatility and sharp ratio: [0.0008243  0.01077815 0.07647923]
# From 2019-12-01 to 2020-01-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00213322 0.02897278 0.07362844]
# From 2020-01-01 to 2020-02-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1.]
# Expected return, volatility and sharp ratio: [-0.00150839  0.04180887 -0.0360782 ]
# From 2020-02-01 to 2020-03-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0.]
# Expected return, volatility and sharp ratio: [-0.0001032   0.04150709 -0.00248634]
# From 2020-03-01 to 2020-04-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.826 0.174 0.   ]
# Expected return, volatility and sharp ratio: [0.00082894 0.03452533 0.02400967]
# From 2020-04-01 to 2020-05-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.911 0.089 0.   ]
# Expected return, volatility and sharp ratio: [0.00082344 0.04420065 0.01862958]
# From 2020-05-01 to 2020-06-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.948 0.052 0.   ]
# Expected return, volatility and sharp ratio: [0.00082258 0.04160548 0.01977105]
# From 2020-06-01 to 2020-07-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.388 0.612 0.   ]
# Expected return, volatility and sharp ratio: [0.00082573 0.01743349 0.04736482]
# From 2020-07-01 to 2020-08-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00165348 0.0183813  0.08995459]
# From 2020-08-01 to 2020-09-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00042555 0.03761954 0.01131186]
# From 2020-09-01 to 2020-10-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.046 0.544 0.41 ]
# Expected return, volatility and sharp ratio: [0.00082141 0.01541847 0.05327454]
# From 2020-10-01 to 2020-11-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0.]
# Expected return, volatility and sharp ratio: [0.00278992 0.02392818 0.11659573]
# From 2020-11-01 to 2020-12-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.273 0.591 0.136]
# Expected return, volatility and sharp ratio: [0.00082335 0.00794887 0.10358051]
# From 2020-12-01 to 2021-01-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.635 0.365 0.   ]
# Expected return, volatility and sharp ratio: [0.00082472 0.01510275 0.05460751]
# From 2021-01-01 to 2021-02-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.    0.624 0.376]
# Expected return, volatility and sharp ratio: [0.00082027 0.00678897 0.12082459]
# From 2021-02-01 to 2021-03-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00011127 0.03219794 0.00345582]
# From 2021-03-01 to 2021-04-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.727 0.273 0.   ]
# Expected return, volatility and sharp ratio: [0.00082232 0.01009134 0.08148742]
# From 2021-04-01 to 2021-05-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.183 0.482 0.335]
# Expected return, volatility and sharp ratio: [0.00082494 0.01145162 0.07203724]
# From 2021-05-01 to 2021-06-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.299 0.633 0.069]
# Expected return, volatility and sharp ratio: [0.00082307 0.00548201 0.15014025]
# From 2021-06-01 to 2021-07-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0.]
# Expected return, volatility and sharp ratio: [-0.00155887  0.02339758 -0.06662536]
# From 2021-07-01 to 2021-08-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.    0.475 0.525]
# Expected return, volatility and sharp ratio: [0.00082559 0.00956073 0.08635251]
# From 2021-08-01 to 2021-09-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00079367 0.02405075 0.03299965]
# From 2021-09-01 to 2021-10-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.277 0.681 0.042]
# Expected return, volatility and sharp ratio: [0.00082555 0.0126095  0.06547034]
# From 2021-10-01 to 2021-11-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.026 0.743 0.231]
# Expected return, volatility and sharp ratio: [0.00082184 0.01516771 0.0541838 ]
# From 2021-11-01 to 2021-12-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.074 0.282 0.643]
# Expected return, volatility and sharp ratio: [0.00082463 0.01476131 0.05586396]
# From 2021-12-01 to 2022-01-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.368 0.134 0.498]
# Expected return, volatility and sharp ratio: [0.00082405 0.01830416 0.04502006]
# From 2022-01-01 to 2022-02-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.017 0.983 0.   ]
# Expected return, volatility and sharp ratio: [0.0008254  0.04105494 0.02010487]
# From 2022-02-01 to 2022-03-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.688 0.312 0.   ]
# Expected return, volatility and sharp ratio: [0.00082373 0.01982753 0.04154485]
# From 2022-03-01 to 2022-04-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0.]
# Expected return, volatility and sharp ratio: [-0.01134897  0.02789631 -0.40682685]
# From 2022-04-01 to 2022-05-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.729 0.271 0.   ]
# Expected return, volatility and sharp ratio: [0.00082334 0.02590464 0.03178361]
# From 2022-05-01 to 2022-06-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0.]
# Expected return, volatility and sharp ratio: [-0.00680046  0.03383692 -0.2009776 ]
# From 2022-06-01 to 2022-07-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00153277 0.0303678  0.05047358]
# From 2022-07-01 to 2022-08-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0.]
# Expected return, volatility and sharp ratio: [-0.00143771  0.01896259 -0.07581801]
# From 2022-08-01 to 2022-09-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1.]
# Expected return, volatility and sharp ratio: [-0.0051327   0.02998077 -0.17119988]
# From 2022-09-01 to 2022-10-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.43 0.57 0.  ]
# Expected return, volatility and sharp ratio: [0.00082219 0.02411341 0.03409698]
# From 2022-10-01 to 2022-11-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.196 0.804 0.   ]
# Expected return, volatility and sharp ratio: [0.00082312 0.03072654 0.02678861]
# From 2022-11-01 to 2022-12-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.424 0.151 0.425]
# Expected return, volatility and sharp ratio: [0.00082081 0.01644257 0.04991998]
# From 2022-12-01 to 2023-01-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00701673 0.01838891 0.38157398]
# From 2023-01-01 to 2023-02-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.873 0.    0.127]
# Expected return, volatility and sharp ratio: [0.00082766 0.01021525 0.08102194]
# From 2023-02-01 to 2023-03-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.293 0.384 0.323]
# Expected return, volatility and sharp ratio: [0.00082748 0.01925686 0.04297091]
# From 2023-03-01 to 2023-04-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [1. 0. 0.]
# Expected return, volatility and sharp ratio: [0.00116283 0.01239979 0.09377802]
# From 2023-04-01 to 2023-05-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.573 0.147 0.28 ]
# Expected return, volatility and sharp ratio: [0.00082345 0.01192518 0.06905111]
# From 2023-05-01 to 2023-06-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00100723 0.01515273 0.06647174]
# From 2023-06-01 to 2023-07-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0.]
# Expected return, volatility and sharp ratio: [0.00138018 0.01696581 0.08135089]
# From 2023-07-01 to 2023-08-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.706 0.235 0.058]
# Expected return, volatility and sharp ratio: [0.00082377 0.01271151 0.06480531]
# From 2023-08-01 to 2023-09-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 0. 1.]
# Expected return, volatility and sharp ratio: [0.00048109 0.01678675 0.02865913]
# From 2023-09-01 to 2023-10-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0.474 0.156 0.37 ]
# Expected return, volatility and sharp ratio: [0.00082424 0.01521119 0.05418609]
# From 2023-10-01 to 2023-11-01 was selected ['GE', 'AMZN', 'DB']
#
# Optimal portfolio: [0. 1. 0.]
# Expected return, volatility and sharp ratio: [0.0032121  0.01219718 0.26334734]
# From 2023-11-01 to 2023-12-01 was selected ['GE', 'AMZN', 'DB']
# Optimal portfolio: [0. 1. 0.]
# Expected return, volatility and sharp ratio: [0.0017289  0.01218378 0.14190166]
# -----------------------------------------------------
# ------------------- Final results -------------------
# Selected stock: ['GE', 'AMZN', 'DB']
# Weights: [0. 1. 0.]
# Returns: [ 0.         72.07499695  0.        ]
# -----------------------------------------------------
